# %%
! pipenv install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey/survey_results_public.csv')
schema_df = pd.read_csv('data/survey/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc CurrencySymbol  \
# 64451            NaN         Poland          NaN            NaN
# ...

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes  NaN         13  Monthly        NaN            NaN
# 1       No  NaN         19      NaN        NaN            NaN
# 2      Yes  NaN         15      NaN        NaN            NaN
#
#               Country    CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0             Germany   European Euro            EUR   Microsoft SQL Server
# 1      United Kingdom  Pound sterling            GBP                    NaN
# 2  Russian Federation             NaN            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
#
# ...

# %%
# we setup the index when we load the data
df = pd.read_csv('data/survey/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey/survey_results_schema.csv', index_col='Column')

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
# get the location of the indexed column easily now 
schema_df.loc['OrgSize', 'QuestionText']
# Out:
# 'Approximately how many people are employed by the company or organization you currently work for?'

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
#filters
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
filt
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 64858    False
# 64867     True
# 64898    False
# 64925    False
# 65112    False
# Name: LanguageWorkedWith, Length: 64461, dtype: bool

# %%
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 3                                 I code primarily as a hobby      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 10                             I am a developer by profession      Yes  22.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# 15                     I am a student who is learning to code      Yes   NaN
# ...                                                       ...      ...   ...
# 61561                                                     NaN      Yes  64.0
# 62391                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 63640                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
#
# ...

# %%
#update data
# update column name
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
# update Yes to True and No to False
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
# to save changes 
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN     True   NaN
# 64867                                                     NaN     True   NaN
# 64898                                                     NaN     True   NaN
# 64925                                                     NaN     True   NaN
# 65112                                                     NaN     True   NaN
#
# ...

# %%
# Add/Remove rows and columns

# %%
# sort data 
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(30)
# Out:
#                 Country  SalaryUSD
# Respondent
# 62788       Afghanistan  1000000.0
# 65381       Afghanistan  1000000.0
# 65456       Afghanistan  1000000.0
# 38672       Afghanistan   231192.0
# 28374       Afghanistan   130000.0
# 9839        Afghanistan    23328.0
# 63848       Afghanistan    23328.0
# 51862       Afghanistan    20950.0
# 51509       Afghanistan    20220.0
# 44484       Afghanistan    18660.0
# 15422       Afghanistan    18000.0
# 2932        Afghanistan    16335.0
# 26540       Afghanistan    13992.0
# 57269       Afghanistan    10884.0
# 26775       Afghanistan     8016.0
# 30568       Afghanistan     5448.0
# 30522       Afghanistan     4668.0
# 28811       Afghanistan     4509.0
# 34969       Afghanistan     4356.0
# 26857       Afghanistan     2328.0
# 33878       Afghanistan     1860.0
# 35753       Afghanistan      780.0
# 18049       Afghanistan      109.0
# 35295       Afghanistan        0.0
# 898         Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 35295       I am a developer by profession     True   NaN         13  Monthly
# 47357       I am a developer by profession     True   NaN          5   Weekly
# 6054        I am a developer by profession     True  38.0         15   Yearly
# 27135       I am a developer by profession    False   NaN         16   Yearly
# 60292       I am a developer by profession     True   NaN         12   Yearly
# 38813       I am a developer by profession    False   NaN         18  Monthly
# 8470        I am a developer by profession     True   NaN          5  Monthly
# 41006       I am a developer by profession     True  22.0         17   Yearly
# 15493       I am a developer by profession    False  44.0         17  Monthly
# 57369       I am a developer by profession    False  44.0         18  Monthly
#
#             CompTotal  SalaryUSD      Country        CurrencyDesc  \
# Respondent
# ...

# %%
# Grouping-Aggregates
df['SalaryUSD'].head(15)
# Out:
# Respondent
# 62788    1000000.0
# 65381    1000000.0
# 65456    1000000.0
# 38672     231192.0
# 28374     130000.0
# 9839       23328.0
# 63848      23328.0
# 51862      20950.0
# 51509      20220.0
# 44484      18660.0
# 15422      18000.0
# 2932       16335.0
# 26540      13992.0
# 57269      10884.0
# 26775       8016.0
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Hobbyist           1.0
# Age               29.0
# CompTotal      63000.0
# SalaryUSD      54049.0
# WorkWeekHrs       40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal     SalaryUSD   WorkWeekHrs
# count  45446.000000   3.482600e+04  3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242  1.037561e+05     40.782174
# std        9.585392            inf  2.268853e+05     17.816383
# min        1.000000   0.000000e+00  0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04  2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04  5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05  9.500000e+04     44.000000
# max      279.000000  1.111111e+247  2.000000e+06    475.000000

# %%
df['SalaryUSD'].count()
# Out:
# 34756

# %%
df['Hobbyist']
# Out:
# Respondent
# 62788     True
# 65381    False
# 65456     True
# 38672    False
# 28374     True
#          ...
# 60055    False
# 61121     True
# 61570    False
# 61918     True
# 62605    False
# Name: Hobbyist, Length: 64461, dtype: object

# %%
#count for each value in the columns 
df['Hobbyist'].value_counts()
# Out:
# True     50388
# False    14028
# Name: Hobbyist, dtype: int64

# %%
df['PlatformWorkedWith']
# Out:
# Respondent
# 62788              NaN
# 65381              NaN
# 65456              NaN
# 38672              NaN
# 28374    Android;Linux
#              ...
# 60055              NaN
# 61121              NaN
# 61570              NaN
# 61918              NaN
# 62605              NaN
# Name: PlatformWorkedWith, Length: 64461, dtype: object

# %%
schema_df.loc['PlatformWorkedWith']
# Out:
# QuestionText    Which platforms have you done extensive develo...
# Name: PlatformWorkedWith, dtype: object

# %%
df['PlatformWorkedWith'].value_counts()
# Out:
# Windows                                                                                            4770
# Linux;Windows                                                                                      2461
# Linux                                                                                              2112
# Android                                                                                            1201
# Microsoft Azure;Windows                                                                             996
#                                                                                                    ...
# Android;Arduino;Heroku;iOS;Windows;WordPress                                                          1
# AWS;Google Cloud Platform;Kubernetes;Raspberry Pi                                                     1
# AWS;Docker;Google Cloud Platform;Linux;MacOS;Raspberry Pi;Slack Apps and Integrations;WordPress       1
# ...

# %%
# get percentages 
df['PlatformWorkedWith'].value_counts(normalize=True)
# Out:
# Windows                                                                                            0.088591
# Linux;Windows                                                                                      0.045707
# Linux                                                                                              0.039225
# Android                                                                                            0.022306
# Microsoft Azure;Windows                                                                            0.018498
#                                                                                                      ...
# Android;Arduino;Heroku;iOS;Windows;WordPress                                                       0.000019
# AWS;Google Cloud Platform;Kubernetes;Raspberry Pi                                                  0.000019
# AWS;Docker;Google Cloud Platform;Linux;MacOS;Raspberry Pi;Slack Apps and Integrations;WordPress    0.000019
# ...

# %%
df['Country'].value_counts()
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Fiji                                      1
# Gabon                                     1
# Micronesia, Federated States of...        1
# Grenada                                   1
# Lesotho                                   1
# Name: Country, Length: 183, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Iraq')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 29159                          I am a developer by profession     True  37.0
# 10501                          I am a developer by profession     True  21.0
# 6649                           I am a developer by profession     True  23.0
# 35608                          I am a developer by profession     True   NaN
# 56010       I am not primarily a developer, but I write co...     True  29.0
# 56670                          I am a developer by profession    False  29.0
# 35897                          I am a developer by profession     True   NaN
# 13485                          I am a developer by profession     True   NaN
# 57619       I am not primarily a developer, but I write co...    False   NaN
# 28622                          I am a developer by profession     True  25.0
# 55836                          I am a developer by profession     True  25.0
# ...

# %%
filt = df['Country'] == 'Iraq'
df.loc[filt]['PlatformWorkedWith'].value_counts()
# Out:
# Windows                                                                   6
# Android                                                                   3
# Linux;Windows                                                             2
# Microsoft Azure;Windows                                                   2
# Android;Arduino;Linux;Windows;WordPress                                   1
# Arduino;AWS;Docker;Linux;Raspberry Pi;Windows                             1
# Android;Google Cloud Platform;iOS;Linux;MacOS                             1
# Docker;Linux                                                              1
# AWS;Linux;MacOS;Raspberry Pi                                              1
# Arduino;Windows                                                           1
# Android;Arduino                                                           1
# Android;Microsoft Azure                                                   1
# ...

# %%
country_grp['PlatformWorkedWith'].value_counts(normalize=True).loc['China']
# Out:
# PlatformWorkedWith
# Windows                                 0.127737
# Linux;Windows                           0.098540
# Android;Linux;Windows                   0.036496
# Linux                                   0.036496
# Docker;Linux;MacOS                      0.029197
#                                           ...
# Linux;Raspberry Pi;Windows;WordPress    0.003650
# Microsoft Azure                         0.003650
# Raspberry Pi;Windows                    0.003650
# WordPress                               0.003650
# iOS                                     0.003650
# Name: PlatformWorkedWith, Length: 130, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 5964

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-cda55dd00399> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# c:\users\raady\.virtualenvs\jupi-ihmijv5r\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Fiji                                      1
# Gabon                                     1
# Micronesia, Federated States of...        1
# Grenada                                   1
# Lesotho                                   1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                     Country  LanguageWorkedWith
# United States                         12469                5964
# India                                  8403                2670
# United Kingdom                         3896                1621
# Germany                                3890                1712
# Canada                                 2191                1011
# ...                                     ...                 ...
# Fiji                                      1                   0
# Gabon                                     1                   1
# Micronesia, Federated States of...        1                   1
# Grenada                                   1                   0
# Lesotho                                   1                   0
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                                     NumRespondents  NumKnowsPython
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Fiji                                             1               0
# Gabon                                            1               1
# Micronesia, Federated States of...               1               1
# Grenada                                          1               0
# Lesotho                                          1               0
#
# [183 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                     NumRespondents  NumKnowsPython  \
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Fiji                                             1               0
# Gabon                                            1               1
# Micronesia, Federated States of...               1               1
# Grenada                                          1               0
# Lesotho                                          1               0
#
#                                     PctKnowsPython
# United States                            47.830620
# India                                    31.774366
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                       NumRespondents  NumKnowsPython  \
# Saint Lucia                                        1               1
# Micronesia, Federated States of...                 1               1
# Gabon                                              1               1
# Montenegro                                        13               9
# Brunei Darussalam                                  3               2
# Guyana                                             5               3
# Swaziland                                          7               4
# Iceland                                           53              28
# Finland                                          349             183
# Uganda                                            81              42
# Mauritania                                         4               2
# Solomon Islands                                    2               1
# Burkina Faso                                       6               3
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    297.000000
# NumKnowsPython    132.000000
# PctKnowsPython     44.444444
# Name: Japan, dtype: float64

# %%
#cleaning data 
df['YearsCode'].head(10)
# Out:
# Respondent
# 62788                   NaN
# 65381                    30
# 65456    More than 50 years
# 38672                    40
# 28374                    17
# 9839                     10
# 63848                    14
# 51862                     5
# 51509                     8
# 44484                     8
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '30', 'More than 50 years', '40', '17', '10', '14', '5', '8',
#        '9', '4', '6', '3', '2', '35', '1', 'Less than 1 year', '7', '12',
#        '50', '19', '20', '11', '15', '24', '27', '28', '16', '22', '13',
#        '18', '25', '38', '34', '23', '32', '21', '42', '33', '26', '29',
#        '39', '48', '36', '47', '41', '37', '31', '43', '44', '45', '46',
#        '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)

# %%
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.709052770265584

# %%
df['YearsCode'].median()
# Out:
# 10.0

# %%
#datetime timeseries 
from datetime import datetime

d_parser = lambda x: datetime.strptime(x, '%Y-%m-%d %I-%p')
crp_df = pd.read_csv('data/ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)

# %%
crp_df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
crp_df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
crp_df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
crp_df['DayOfWeek'] = crp_df['Date'].dt.day_name()
crp_df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
crp_df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
crp_df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
crp_df['Date'].max() - crp_df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (crp_df['Date'] >= pd.to_datetime('2019-01-01')) & (crp_df['Date'] < pd.to_datetime('2020-01-01'))
crp_df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
crp_df.set_index('Date', inplace=True)

# %%
crp_df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
crp_df.loc['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     DayOfWeek
# Date
# 2019-12-31 23:00:00   Tuesday
# ...

# %%
crp_df['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
crp_df['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.1655902777778

# %%
crp_df.loc['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
highs = crp_df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
! pipenv install matplotlib
# %matplotlib inline
# Out:
# [    ] Installing...
# [=   ] Installing matplotlib...
# [==  ] Installing matplotlib...
# [=== ] Installing matplotlib...
# [ ===] Installing matplotlib...
# [  ==] Installing matplotlib...
# [   =] Installing matplotlib...
# [    ] Installing matplotlib...
# [   =] Installing matplotlib...
# [  ==] Installing matplotlib...
# [ ===] Installing matplotlib...
# [====] Installing matplotlib...
# [=== ] Installing matplotlib...
# [==  ] Installing matplotlib...
# [=   ] Installing matplotlib...
# [    ] Installing matplotlib...
# [=   ] Installing matplotlib...
# [==  ] Installing matplotlib...
# [=== ] Installing matplotlib...
# [ ===] Installing matplotlib...
# [  ==] Installing matplotlib...
# [   =] Installing matplotlib...
# [    ] Installing matplotlib...
# [   =] Installing matplotlib...
# [  ==] Installing matplotlib...
# [ ===] Installing matplotlib...
# [====] Installing matplotlib...
# [=== ] Installing matplotlib...
# [==  ] Installing matplotlib...
# ...

# %%
highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
crp_df.resample('W').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
crp_df.resample('W').agg({'Close': 'mean', 'High': 'max', 'Low': 'min', 'Volume': 'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %%
# import and export

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#      Respondent                              MainBranch Hobbyist   Age  \
# 6             7          I am a developer by profession      Yes   NaN
# 21           22          I am a developer by profession      Yes   NaN
# 57           58          I am a developer by profession      Yes   NaN
# 62           63  I am a student who is learning to code      Yes  21.0
# 147         149          I am a developer by profession      Yes  36.0
#
#     Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# 6           18  Monthly         NaN            NaN   India
# 21          18  Monthly         NaN            NaN   India
# 57          22      NaN         NaN            NaN   India
# 62          17      NaN         NaN            NaN   India
# 147         31   Yearly  21000000.0       293196.0   India
#
#              CurrencyDesc CurrencySymbol      DatabaseDesireNextYear  \
# 6    United States dollar            USD                         NaN
# ...

# %%
india_df.to_csv('data/modified.csv')

# %%
india_df.to_csv('data/modified.tsv', sep='\t')

# %%
india_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx', index_col='Respondent')

# %%
test.head()

# %%
india_df.to_json('data/modified.json', orient='records', lines=True)

# %%
test = pd.read_json('data/modified.json', orient='records', lines=True)

# %%
test.head()
# Out:
#    Respondent                              MainBranch Hobbyist   Age  \
# 0           7          I am a developer by profession      Yes   NaN
# 1          22          I am a developer by profession      Yes   NaN
# 2          58          I am a developer by profession      Yes   NaN
# 3          63  I am a student who is learning to code      Yes  21.0
# 4         149          I am a developer by profession      Yes  36.0
#
#   Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# 0         18  Monthly         NaN            NaN   India
# 1         18  Monthly         NaN            NaN   India
# 2         22     None         NaN            NaN   India
# 3         17     None         NaN            NaN   India
# 4         31   Yearly  21000000.0       293196.0   India
#
#            CurrencyDesc CurrencySymbol      DatabaseDesireNextYear  \
# 0  United States dollar            USD                        None
# 1          Indian rupee            INR                        None
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
india_df.to_sql('sample_table', engine, if_exists='replace')

# %%
sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')

# %%
sql_df.head()

# %%
sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='Respondent')

# %%
sql_df.head()

# %%
posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
posts_df.head()
# Out:
#                           title  \
# 0               My Updated Post
# 1                 A Second Post
# 2  Top 5 Programming Lanaguages
# 3  Sublime Text Tips and Tricks
# 4              Best Python IDEs
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1

# %%
data = [ 
          (20, 16, 23), 
          (30, None, 11), 
          (40, 34, 11), 
          (50, 35, None), 
          (60, 40, 13) 
        ]
df_test =pd.DataFrame(data)
df_test.min()
# Out:
# 0    20.0
# 1    16.0
# 2    11.0
# dtype: float64
